# %% [markdown]
# <a href="https://colab.research.google.com/github/prithiba-A/Mini_Project_12-Tweets_Search-Download/blob/main/Mini_Project_12_Tweets_Search_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy

# %%
import tweepy

# %%
# Set your Twitter API credentials
consumer_key = "we0Drpnvc1FZNazKkiKoFWlGf"
consumer_secret = "OXRvmJwM6ca9k90XMIMoktSCa5XvjNieqJivcfjbOAlmpO6RhH"
access_token = "501682241-ZG1DshytyxUIUY8FXPoH2AXaDG9d5DQlORemfAzU"
access_token_secret = "mxwCYkDjgWG5qWy8ONtVs3j2lxiYSxyberVVa92jmd27z"

# %%
# Authenticate with Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
search_words = "#IPL"
date_since = "2022-04-16"

# %%
tweets = tw.Cursor(api.search_tweets, q=search_words, lang="en", since=date_since).items(5)

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# WARNING:tweepy.api:Unexpected parameter: since
# You can download for free and use for free the TunnTunn mobile app from the following links.
# FOR IOS:… https://t.co/GB9U57dedK
# 5 Reason West Indies Fail to Qualify for ODI World Cup 2023 🏏
#
# 👇👇👇👇👇
# https://t.co/TkQ40Zo7tP
#
# #worldcup… https://t.co/2OzcLSEVEj
# Not playing #IPL since 2016 , Values test cricket over anything. The biggest clutch player of this era and one of t… https://t.co/ZP8uD94LOa
# Dhundo Dhundo Re Saajna: When #SunilGavaskar  HILARIOUSLY Took A Dig At #RohitSharma On Commentary | WATCH
#
# #IPL
#
# https://t.co/l25bjXkcRK
# RT @vedhavalli_13: My go to man since 2009 to till date and forever. Wishing you a very happy birthday mahi bhai.🎂see u soon in yellow💛 #re…

# %%
df=pd.read_csv('/content/malaria.csv')
df
# Out:
#                                 Country  Year              No. of cases  \
# 0                           Afghanistan  2017     630308[495000-801000]
# 1                               Algeria  2017                         0
# 2                                Angola  2017  4615605[3106000-6661000]
# 3                             Argentina  2017                         0
# 4                               Armenia  2017                         0
# ..                                  ...   ...                       ...
# 851  Venezuela (Bolivarian Republic of)  2010        57257[47000-74000]
# 852                            Viet Nam  2010        23062[21000-26000]
# 853                               Yemen  2010   1134927[611000-2686000]
# 854                              Zambia  2010  2169307[1449000-3095000]
# 855                            Zimbabwe  2010   1095083[606000-1717000]
#
#          No. of deaths  No. of cases_median  No. of cases_min  \
# ...

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = " ".join(review for review in df.Country)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 9511 words in the combination of all review.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)

# %%
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,10) )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud

# %%
df["Year"] = df['Country'].str.lower().str.replace('[^\w\s]','')


new_df = df.Year.str.split(expand=True).stack().value_counts().reset_index()

new_df.columns = ['Word', 'Frequency']

new_df.head(10)
# Out:
# <ipython-input-100-0519d6a4a54d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Year"] = df['Country'].str.lower().str.replace('[^\w\s]','')
#          Word  Frequency
# 0    republic         80
# 1          of         56
# 2  democratic         24
# 3      guinea         24
# 4       south         16
# 5       sudan         16
# 6       korea         16
# 7     peoples         16
# 8       congo         16
# 9        arab         16
